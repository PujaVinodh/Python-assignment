# %%
import pandas as pd
import csv
data=pd.read_csv(r'C:\Users\Ramuksk\Documents\PythonCSV.csv')
print(data)
# Out:
#                    States/Uts  Number of Road Accidents - Total -2006  \
# 0              Andhra Pradesh                                  6635.0
# 1           Arunachal Pradesh                                    40.0
# 2                       Assam                                   678.0
# 3                       Bihar                                   802.0
# 4                Chhattisgarh                                  2694.0
# 5                         Goa                                  1301.0
# 6                     Gujarat                                  5912.0
# 7                     Haryana                                  1148.0
# 8            Himachal Pradesh                                   502.0
# 9             Jammu & Kashmir                                   912.0
# 10                  Jharkhand                                  1441.0
# 11                  Karnataka                                  9990.0
# ...

# %%
data.columns[1:12]
# Out:
# Index(['Number of Road Accidents - Total -2006',
#        'Number of Road Accidents - Total -2007',
#        'Number of Road Accidents - Total -2008',
#        'Number of Road Accidents - Total -2009',
#        'Number of Road Accidents - Total -2010',
#        'Number of Road Accidents - Total -2011',
#        'Number of Road Accidents - Total -2012',
#        'Number of Road Accidents - Total -2013',
#        'Number of Road Accidents - Total -2014',
#        'Number of Road Accidents - Total -2015',
#        'Number of Road Accidents ( Motor Cycle/ Scooter ) - Total -2016'],
#       dtype='object')

# %%
data.iloc[11]
# Out:
# States/Uts                                                               Karnataka
# Number of Road Accidents - Total -2006                                        9990
# Number of Road Accidents - Total -2007                                       11487
# Number of Road Accidents - Total -2008                                       11118
# Number of Road Accidents - Total -2009                                       10731
# Number of Road Accidents - Total -2010                                       12133
# Number of Road Accidents - Total -2011                                       10780
# Number of Road Accidents - Total -2012                                       10588
# Number of Road Accidents - Total -2013                                       12356
# Number of Road Accidents - Total -2014                                       10752
# Number of Road Accidents - Total -2015                                       13155
# ...

# %%
data.iloc[11].as_matrix()
# Out:
# c:\users\ramuksk\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# array(['Karnataka', 9990.0, 11487.0, 11118.0, 10731.0, 12133.0, 10780.0,
#        10588.0, 12356.0, 10752, 13155, 14965, 1252, 1457.0, 1755.0,
#        1803.0, 1700.0, 1872.0, 1821.0, 1891.0, 2271.0, 2473, 2803, 3596,
#        274, 1566.0, 1912.0, 1824.0, 1837.0, 2041.0, 1961.0, 2081.0,
#        2406.0, 3040, 2993, 3832, 287, 11611.0, 13603.0, 12344.0, 12791.0,
#        13490.0, 12765.0, 12565.0, 13577.0, 13930, 14016, 7691, 8517, 738,
#        1007], dtype=object)

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(18,18), dpi=180, facecolor='w', edgecolor='k')
ax=fig.add_axes([0,0,1,1])
arr=[]
for i in data.columns:
    arr.append(i[-4:])
print(arr)

ax.bar(arr[1:12],data.iloc[11].as_matrix()[1:12])
fig.suptitle('KARNATAKA',fontsize=30)
plt.xlabel('YEARS',fontsize=20)
plt.ylabel('NUMBER OF ROAD ACCIDENTS',fontsize=20)
plt.show();
# Out:
# ['/Uts', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2016', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2016', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2016', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2016', '2016', '2016']
# c:\users\ramuksk\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':
